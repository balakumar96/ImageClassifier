# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/rafa.jpg')
img.shape
# Out:
# (3648, 5472, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (3648, 5472)

# %%
gray
# Out:
# array([[ 7,  6,  5, ...,  1,  2,  2],
#        [ 5,  4,  4, ...,  1,  1,  2],
#        [ 6,  5,  5, ...,  2,  2,  2],
#        ...,
#        [56, 58, 59, ..., 86, 90, 94],
#        [53, 56, 59, ..., 85, 88, 90],
#        [54, 57, 59, ..., 86, 88, 90]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[1844,  891, 1637, 1637]])

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (1844, 891, 1637, 1637)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),15)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),10)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (1637, 1637, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/rafa.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/rafa.jpg')
plt.imshow(cropped_image)

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
org_image_obstructed = cv2.imread('./test_images/rafa2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/rafa2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/AB De',
#  './dataset/Kaka',
#  './dataset/Kohli',
#  './dataset/Mathews',
#  './dataset/Nadal']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# AB De
# Generating cropped images in folder:  ./dataset/cropped/AB De
# Kaka
# Generating cropped images in folder:  ./dataset/cropped/Kaka
# Kohli
# Generating cropped images in folder:  ./dataset/cropped/Kohli
# Mathews
# Generating cropped images in folder:  ./dataset/cropped/Mathews
# Nadal
# Generating cropped images in folder:  ./dataset/cropped/Nadal

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'AB De': ['./dataset/cropped/AB De\\AB De1.png',
#   './dataset/cropped/AB De\\AB De10.png',
#   './dataset/cropped/AB De\\AB De11.png',
#   './dataset/cropped/AB De\\AB De12.png',
#   './dataset/cropped/AB De\\AB De13.png',
#   './dataset/cropped/AB De\\AB De14.png',
#   './dataset/cropped/AB De\\AB De15.png',
#   './dataset/cropped/AB De\\AB De16.png',
#   './dataset/cropped/AB De\\AB De17.png',
#   './dataset/cropped/AB De\\AB De2.png',
#   './dataset/cropped/AB De\\AB De3.png',
#   './dataset/cropped/AB De\\AB De4.png',
#   './dataset/cropped/AB De\\AB De5.png',
#   './dataset/cropped/AB De\\AB De6.png',
#   './dataset/cropped/AB De\\AB De7.png',
#   './dataset/cropped/AB De\\AB De8.png',
#   './dataset/cropped/AB De\\AB De9.png'],
#  'Kaka': ['./dataset/cropped/Kaka\\Kaka1.png',
#   './dataset/cropped/Kaka\\Kaka10.png',
#   './dataset/cropped/Kaka\\Kaka11.png',
#   './dataset/cropped/Kaka\\Kaka12.png',
#   './dataset/cropped/Kaka\\Kaka13.png',
#   './dataset/cropped/Kaka\\Kaka14.png',
#   './dataset/cropped/Kaka\\Kaka15.png',
#   './dataset/cropped/Kaka\\Kaka16.png',
#   './dataset/cropped/Kaka\\Kaka17.png',
#   './dataset/cropped/Kaka\\Kaka18.png',
#   './dataset/cropped/Kaka\\Kaka19.png',
#   './dataset/cropped/Kaka\\Kaka2.png',
#   './dataset/cropped/Kaka\\Kaka20.png',
#   './dataset/cropped/Kaka\\Kaka21.png',
#   './dataset/cropped/Kaka\\Kaka22.png',
#   './dataset/cropped/Kaka\\Kaka23.png',
#   './dataset/cropped/Kaka\\Kaka24.png',
#   './dataset/cropped/Kaka\\Kaka25.png',
#   './dataset/cropped/Kaka\\Kaka26.png',
#   './dataset/cropped/Kaka\\Kaka27.png',
#   './dataset/cropped/Kaka\\Kaka28.png',
#   './dataset/cropped/Kaka\\Kaka29.png',
#   './dataset/cropped/Kaka\\Kaka3.png',
#   './dataset/cropped/Kaka\\Kaka30.png',
#   './dataset/cropped/Kaka\\Kaka31.png',
#   './dataset/cropped/Kaka\\Kaka32.png',
#   './dataset/cropped/Kaka\\Kaka33.png',
#   './dataset/cropped/Kaka\\Kaka34.png',
#   './dataset/cropped/Kaka\\Kaka35.png',
#   './dataset/cropped/Kaka\\Kaka36.png',
#   './dataset/cropped/Kaka\\Kaka37.png',
#   './dataset/cropped/Kaka\\Kaka38.png',
#   './dataset/cropped/Kaka\\Kaka39.png',
#   './dataset/cropped/Kaka\\Kaka4.png',
#   './dataset/cropped/Kaka\\Kaka40.png',
#   './dataset/cropped/Kaka\\Kaka41.png',
#   './dataset/cropped/Kaka\\Kaka42.png',
#   './dataset/cropped/Kaka\\Kaka5.png',
#   './dataset/cropped/Kaka\\Kaka6.png',
#   './dataset/cropped/Kaka\\Kaka7.png',
#   './dataset/cropped/Kaka\\Kaka8.png',
#   './dataset/cropped/Kaka\\Kaka9.png'],
#  'Kohli': ['./dataset/cropped/Kohli\\Kohli1.png',
#   './dataset/cropped/Kohli\\Kohli10.png',
#   './dataset/cropped/Kohli\\Kohli11.png',
#   './dataset/cropped/Kohli\\Kohli12.png',
#   './dataset/cropped/Kohli\\Kohli13.png',
#   './dataset/cropped/Kohli\\Kohli14.png',
#   './dataset/cropped/Kohli\\Kohli15.png',
#   './dataset/cropped/Kohli\\Kohli16.png',
#   './dataset/cropped/Kohli\\Kohli17.png',
#   './dataset/cropped/Kohli\\Kohli18.png',
#   './dataset/cropped/Kohli\\Kohli19.png',
#   './dataset/cropped/Kohli\\Kohli2.png',
#   './dataset/cropped/Kohli\\Kohli20.png',
#   './dataset/cropped/Kohli\\Kohli21.png',
#   './dataset/cropped/Kohli\\Kohli22.png',
#   './dataset/cropped/Kohli\\Kohli23.png',
#   './dataset/cropped/Kohli\\Kohli24.png',
#   './dataset/cropped/Kohli\\Kohli25.png',
#   './dataset/cropped/Kohli\\Kohli26.png',
#   './dataset/cropped/Kohli\\Kohli27.png',
#   './dataset/cropped/Kohli\\Kohli28.png',
#   './dataset/cropped/Kohli\\Kohli29.png',
#   './dataset/cropped/Kohli\\Kohli3.png',
#   './dataset/cropped/Kohli\\Kohli30.png',
#   './dataset/cropped/Kohli\\Kohli31.png',
#   './dataset/cropped/Kohli\\Kohli4.png',
#   './dataset/cropped/Kohli\\Kohli5.png',
#   './dataset/cropped/Kohli\\Kohli6.png',
#   './dataset/cropped/Kohli\\Kohli7.png',
#   './dataset/cropped/Kohli\\Kohli8.png',
#   './dataset/cropped/Kohli\\Kohli9.png'],
#  'Mathews': ['./dataset/cropped/Mathews\\Mathews1.png',
#   './dataset/cropped/Mathews\\Mathews10.png',
#   './dataset/cropped/Mathews\\Mathews11.png',
#   './dataset/cropped/Mathews\\Mathews12.png',
#   './dataset/cropped/Mathews\\Mathews13.png',
#   './dataset/cropped/Mathews\\Mathews14.png',
#   './dataset/cropped/Mathews\\Mathews15.png',
#   './dataset/cropped/Mathews\\Mathews16.png',
#   './dataset/cropped/Mathews\\Mathews17.png',
#   './dataset/cropped/Mathews\\Mathews18.png',
#   './dataset/cropped/Mathews\\Mathews19.png',
#   './dataset/cropped/Mathews\\Mathews2.png',
#   './dataset/cropped/Mathews\\Mathews20.png',
#   './dataset/cropped/Mathews\\Mathews21.png',
#   './dataset/cropped/Mathews\\Mathews22.png',
#   './dataset/cropped/Mathews\\Mathews23.png',
#   './dataset/cropped/Mathews\\Mathews3.png',
#   './dataset/cropped/Mathews\\Mathews4.png',
#   './dataset/cropped/Mathews\\Mathews5.png',
#   './dataset/cropped/Mathews\\Mathews6.png',
#   './dataset/cropped/Mathews\\Mathews7.png',
#   './dataset/cropped/Mathews\\Mathews8.png',
#   './dataset/cropped/Mathews\\Mathews9.png'],
#  'Nadal': ['./dataset/cropped/Nadal\\Nadal1.png',
#   './dataset/cropped/Nadal\\Nadal10.png',
#   './dataset/cropped/Nadal\\Nadal11.png',
#   './dataset/cropped/Nadal\\Nadal12.png',
#   './dataset/cropped/Nadal\\Nadal13.png',
#   './dataset/cropped/Nadal\\Nadal14.png',
#   './dataset/cropped/Nadal\\Nadal15.png',
#   './dataset/cropped/Nadal\\Nadal16.png',
#   './dataset/cropped/Nadal\\Nadal17.png',
#   './dataset/cropped/Nadal\\Nadal18.png',
#   './dataset/cropped/Nadal\\Nadal19.png',
#   './dataset/cropped/Nadal\\Nadal2.png',
#   './dataset/cropped/Nadal\\Nadal20.png',
#   './dataset/cropped/Nadal\\Nadal21.png',
#   './dataset/cropped/Nadal\\Nadal22.png',
#   './dataset/cropped/Nadal\\Nadal23.png',
#   './dataset/cropped/Nadal\\Nadal24.png',
#   './dataset/cropped/Nadal\\Nadal25.png',
#   './dataset/cropped/Nadal\\Nadal26.png',
#   './dataset/cropped/Nadal\\Nadal27.png',
#   './dataset/cropped/Nadal\\Nadal28.png',
#   './dataset/cropped/Nadal\\Nadal3.png',
#   './dataset/cropped/Nadal\\Nadal4.png',
#   './dataset/cropped/Nadal\\Nadal5.png',
#   './dataset/cropped/Nadal\\Nadal6.png',
#   './dataset/cropped/Nadal\\Nadal7.png',
#   './dataset/cropped/Nadal\\Nadal8.png',
#   './dataset/cropped/Nadal\\Nadal9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'AB De': 0, 'Kaka': 1, 'Kohli': 2, 'Mathews': 3, 'Nadal': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
X[0]
# Out:
# array([[14],
#        [18],
#        [21],
#        ...,
#        [ 0],
#        [ 0],
#        [ 0]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (141, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)

# %%
print(classification_report(y_test, pipe.predict(X_test)))

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df

# %%
best_estimators

# %%
best_estimators['svm'].score(X_test,y_test)

# %%
best_estimators['random_forest'].score(X_test,y_test)

# %%
best_estimators['logistic_regression'].score(X_test,y_test)

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %%
class_dict

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
